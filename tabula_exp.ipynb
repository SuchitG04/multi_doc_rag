# %%
import tabula

# %%
tabula.convert_into("./AMD.10K.2023.pdf", "output.txt", output_format="json", pages='all', guess=False)

# %%
tabula.convert_into?
# Out:
# Signature:
# tabula.convert_into(
#     input_path: Union[IO, str, os.PathLike],
#     output_path: str,
#     output_format: str = 'csv',
#     java_options: Optional[List[str]] = None,
#     pages: Union[str, int, Iterable[int], NoneType] = None,
#     guess: bool = True,
#     area: Union[Iterable[float], Iterable[Iterable[float]], NoneType] = None,
#     relative_area: bool = False,
#     lattice: bool = False,
#     stream: bool = False,
#     password: Optional[str] = None,
#     silent: Optional[bool] = None,
#     columns: Optional[Iterable[float]] = None,
#     relative_columns: bool = False,
#     format: Optional[str] = None,
#     batch: Optional[str] = None,
#     options: str = '',
# ) -> None
# Docstring:
# Convert tables from PDF into a file.
# Output file will be saved into `output_path`.
#
# Args:
#     input_path (file like obj):
#         File like object of target PDF file.
#     output_path (str):
#         File path of output file.
# ...

# %%
with open("./output.txt") as json_file:
  jsons = json_file.read()

# %%
import json
act_json = json.loads(jsons)

# %%
act_json[0]
# Out:
# {'extraction_method': 'stream',
#  'top': 0.0,
#  'left': 0.0,
#  'width': 612.0,
#  'height': 792.0,
#  'right': 612.0,
#  'bottom': 792.0,
#  'data': [[{'top': 26.38,
#     'left': 23.8,
#     'width': 56.060001373291016,
#     'height': 4.019999980926514,
#     'text': 'Table of Contents'},
#    {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#   [{'top': 49.05,
#     'left': 165.69,
#     'width': 281.0199890136719,
#     'height': 5.360000133514404,
#     'text': 'UNITED STATES SECURITIES AND EXCHANGE COMMISSION'},
#    {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#   [{'top': 59.55,
#     'left': 261.01,
#     'width': 90.37998962402344,
#     'height': 4.46999979019165,
#     'text': 'Washington, D.C. 20549'},
#    {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#   [{'top': 81.17,
#     'left': 274.46,
#     'width': 63.47000503540039,
#     'height': 6.260000228881836,
#     'text': 'FORM 10-K'},
# ...

# %%
dfs = tabula.read_pdf("./AMD.10K.2023.pdf", format="tsv", multiple_tables=True, pages="all")

# %%
print(dfs[9].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 1</th>
#       <th>December 31,</th>
#       <th>Unnamed: 2</th>
#       <th>December 25,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2022</td>
#       <td>NaN</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>(In millions)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>revenue:</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Data Center</td>
#       <td>$</td>
#       <td>6,043</td>
#       <td>$</td>
#       <td>3,694</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Client</td>
#       <td>NaN</td>
#       <td>6,201</td>
# ...
